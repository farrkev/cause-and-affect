# %%
from itertools import combinations, product
import networkx as nx
import pandas as pd
import pickle as pkl

# %%
# generating a pandas df to store similarity scores
all_p_ids = [16,19,21,23,25,26,28,30,34,37,39,41,42,45,46,56,64,65]

layer_1 = ["visual", "audio", "physio"]
layer_2 = ["ges:pruned_fci", "ges:pruned_pc", "pruned_fci:pruned_pc"]

multi_columns = pd.MultiIndex.from_product([layer_1, layer_2])

results_df = pd.DataFrame(index=all_p_ids, columns=multi_columns)
# Out:
#            visual                                             audio  \
#    ges:pruned_fci ges:pruned_pc pruned_fci:pruned_pc ges:pruned_fci
# 16            NaN           NaN                  NaN            NaN
# 19            NaN           NaN                  NaN            NaN
# 21            NaN           NaN                  NaN            NaN
# 23            NaN           NaN                  NaN            NaN
# 25            NaN           NaN                  NaN            NaN
# 26            NaN           NaN                  NaN            NaN
# 28            NaN           NaN                  NaN            NaN
# 30            NaN           NaN                  NaN            NaN
# 34            NaN           NaN                  NaN            NaN
# 37            NaN           NaN                  NaN            NaN
# 39            NaN           NaN                  NaN            NaN
# 41            NaN           NaN                  NaN            NaN
# 42            NaN           NaN                  NaN            NaN
# 45            NaN           NaN                  NaN            NaN
# 46            NaN           NaN                  NaN            NaN
# 56            NaN           NaN                  NaN            NaN
# 64            NaN           NaN                  NaN            NaN
# 65            NaN           NaN                  NaN            NaN
#
#                                               physio                \
#    ges:pruned_pc pruned_fci:pruned_pc ges:pruned_fci ges:pruned_pc
# 16           NaN                  NaN            NaN           NaN
# 19           NaN                  NaN            NaN           NaN
# 21           NaN                  NaN            NaN           NaN
# 23           NaN                  NaN            NaN           NaN
# 25           NaN                  NaN            NaN           NaN
# 26           NaN                  NaN            NaN           NaN
# 28           NaN                  NaN            NaN           NaN
# 30           NaN                  NaN            NaN           NaN
# 34           NaN                  NaN            NaN           NaN
# 37           NaN                  NaN            NaN           NaN
# 39           NaN                  NaN            NaN           NaN
# 41           NaN                  NaN            NaN           NaN
# 42           NaN                  NaN            NaN           NaN
# 45           NaN                  NaN            NaN           NaN
# 46           NaN                  NaN            NaN           NaN
# 56           NaN                  NaN            NaN           NaN
# 64           NaN                  NaN            NaN           NaN
# 65           NaN                  NaN            NaN           NaN
#
#
#    pruned_fci:pruned_pc
# 16                  NaN
# 19                  NaN
# 21                  NaN
# 23                  NaN
# 25                  NaN
# 26                  NaN
# 28                  NaN
# 30                  NaN
# 34                  NaN
# 37                  NaN
# 39                  NaN
# 41                  NaN
# 42                  NaN
# 45                  NaN
# 46                  NaN
# 56                  NaN
# 64                  NaN
# 65                  NaN

# %%
def get_edges(dag_path, method:str):
    with open(dag_path, "rb") as file:
        dag_data = pkl.load(file)

    graph_matrix = (
        dag_data["G"].graph if method == "ges" 
        else dag_data[0].graph if method in ["fci", "pruned_fci"]
        else dag_data.G.graph if method in ["pc", "pruned_pc"]
        else dag_data if method == "avg"
        else None
    )

    # extract edges from the learned DAG
    num_nodes = graph_matrix.shape[0]
    edges = []

    # iterate through all node pairs to determine edge types
    for i, j in product(range(num_nodes), range(num_nodes)):
        if graph_matrix[i, j] == -1 and graph_matrix[j, i] == 1:  # fully directed edge i --> j
            edges.append((i, j))

    return edges


def jaccard_similarity(graph1_edges, graph2_edges):
    edges1 = set(graph1_edges)
    edges2 = set(graph2_edges)
    intersection = len(edges1 & edges2)
    union = len(edges1 | edges2)
    return intersection / union if union != 0 else 0

# %%
data = {
    "visual": {
        "ges": [16,19,23,25,26,28,30,34,37,39,42,45,46,56,64,65], # missing 21, 41
        "pruned_fci": [16,19,21,23,25,26,28,30,34,37,39,41,42,45,46,56,64,65],
        "pruned_pc": [16,19,21,23,25,26,28,30,34,37,39,41,42,45,46,56,64,65],
    },
    "audio": {
        "ges": [16,19,21,23,25,26,28,30,34,37,39,41,42,45,46,56,64,65],
        "pruned_fci": [16,19,21,23,25,26,28,30,34,37,39,41,42,45,46,56,64,65],
        "pruned_pc": [16,19,21,23,25,26,28,30,34,37,39,41,42,45,46,56,64,65],
    },
    "physio": {
        "ges": [16,19,23,25,26,28,30,34,37,39,41,42,45,46,56,64,65], # missing 21
        "pruned_fci": [16,19,21,23,25,26,28,30,34,37,39,41,42,45,46,56,64,65],
        "pruned_pc": [16,19,21,23,25,26,28,30,34,37,39,41,42,45,46,56,64,65],
    },
}

for modality, methods in data.items():
    method_pairs = list(combinations(methods, 2))
    for pair in method_pairs:
        participants = set(methods[pair[0]]) & set(methods[pair[1]])
        for participant_id in sorted(participants):
            print(f"Processing: {modality}, {participant_id}, {pair[0]}:{pair[1]}")
            dag_path_0 = f"../results_dag/{modality}/{pair[0]}_dag_participant_{participant_id}.pkl"
            dag_path_1 = f"../results_dag/{modality}/{pair[1]}_dag_participant_{participant_id}.pkl"

            edges_0 = get_edges(dag_path_0, pair[0])
            edges_1 = get_edges(dag_path_1, pair[1])

            dag_0 = nx.DiGraph(edges_0)
            dag_1 = nx.DiGraph(edges_1)

            # compute the graph edit distance
            ged = nx.optimize_graph_edit_distance(dag_0, dag_1)

            results_df.loc[participant_id, (modality, f"{pair[0]}:{pair[1]}")] = next(ged)

results_df.to_csv("ged_approximations.csv")
# Out:
# Processing: visual, 16, ges:pruned_fci
# Processing: visual, 19, ges:pruned_fci
# Processing: visual, 23, ges:pruned_fci
# Processing: visual, 25, ges:pruned_fci
# Processing: visual, 26, ges:pruned_fci
# Processing: visual, 28, ges:pruned_fci
# Processing: visual, 30, ges:pruned_fci
# Processing: visual, 34, ges:pruned_fci
# Processing: visual, 37, ges:pruned_fci
# Processing: visual, 39, ges:pruned_fci
# Processing: visual, 42, ges:pruned_fci
# Processing: visual, 45, ges:pruned_fci
# Processing: visual, 46, ges:pruned_fci
# Processing: visual, 56, ges:pruned_fci
# Processing: visual, 64, ges:pruned_fci
# Processing: visual, 65, ges:pruned_fci
# Processing: visual, 16, ges:pruned_pc
# Processing: visual, 19, ges:pruned_pc
# Processing: visual, 23, ges:pruned_pc
# Processing: visual, 25, ges:pruned_pc
# Processing: visual, 26, ges:pruned_pc
# Processing: visual, 28, ges:pruned_pc
# Processing: visual, 30, ges:pruned_pc
# Processing: visual, 34, ges:pruned_pc
# Processing: visual, 37, ges:pruned_pc
# Processing: visual, 39, ges:pruned_pc
# Processing: visual, 42, ges:pruned_pc
# Processing: visual, 45, ges:pruned_pc
# Processing: visual, 46, ges:pruned_pc
# Processing: visual, 56, ges:pruned_pc
# Processing: visual, 64, ges:pruned_pc
# Processing: visual, 65, ges:pruned_pc
# Processing: visual, 16, pruned_fci:pruned_pc
# Processing: visual, 19, pruned_fci:pruned_pc
# Processing: visual, 21, pruned_fci:pruned_pc
# Processing: visual, 23, pruned_fci:pruned_pc
# Processing: visual, 25, pruned_fci:pruned_pc
# Processing: visual, 26, pruned_fci:pruned_pc
# Processing: visual, 28, pruned_fci:pruned_pc
# Processing: visual, 30, pruned_fci:pruned_pc
# Processing: visual, 34, pruned_fci:pruned_pc
# Processing: visual, 37, pruned_fci:pruned_pc
# Processing: visual, 39, pruned_fci:pruned_pc
# Processing: visual, 41, pruned_fci:pruned_pc
# Processing: visual, 42, pruned_fci:pruned_pc
# Processing: visual, 45, pruned_fci:pruned_pc
# Processing: visual, 46, pruned_fci:pruned_pc
# Processing: visual, 56, pruned_fci:pruned_pc
# Processing: visual, 64, pruned_fci:pruned_pc
# Processing: visual, 65, pruned_fci:pruned_pc
# Processing: audio, 16, ges:pruned_fci
# Processing: audio, 19, ges:pruned_fci
# Processing: audio, 21, ges:pruned_fci
# Processing: audio, 23, ges:pruned_fci
# Processing: audio, 25, ges:pruned_fci
# Processing: audio, 26, ges:pruned_fci
# Processing: audio, 28, ges:pruned_fci
# Processing: audio, 30, ges:pruned_fci
# Processing: audio, 34, ges:pruned_fci
# Processing: audio, 37, ges:pruned_fci
# Processing: audio, 39, ges:pruned_fci
# Processing: audio, 41, ges:pruned_fci
# Processing: audio, 42, ges:pruned_fci
# Processing: audio, 45, ges:pruned_fci
# Processing: audio, 46, ges:pruned_fci
# Processing: audio, 56, ges:pruned_fci
# Processing: audio, 64, ges:pruned_fci
# Processing: audio, 65, ges:pruned_fci
# Processing: audio, 16, ges:pruned_pc
# Processing: audio, 19, ges:pruned_pc
# Processing: audio, 21, ges:pruned_pc
# Processing: audio, 23, ges:pruned_pc
# Processing: audio, 25, ges:pruned_pc
# Processing: audio, 26, ges:pruned_pc
# Processing: audio, 28, ges:pruned_pc
# Processing: audio, 30, ges:pruned_pc
# Processing: audio, 34, ges:pruned_pc
# Processing: audio, 37, ges:pruned_pc
# Processing: audio, 39, ges:pruned_pc
# Processing: audio, 41, ges:pruned_pc
# Processing: audio, 42, ges:pruned_pc
# Processing: audio, 45, ges:pruned_pc
# Processing: audio, 46, ges:pruned_pc
# Processing: audio, 56, ges:pruned_pc
# Processing: audio, 64, ges:pruned_pc
# Processing: audio, 65, ges:pruned_pc
# Processing: audio, 16, pruned_fci:pruned_pc
# Processing: audio, 19, pruned_fci:pruned_pc
# Processing: audio, 21, pruned_fci:pruned_pc
# Processing: audio, 23, pruned_fci:pruned_pc
# Processing: audio, 25, pruned_fci:pruned_pc
# Processing: audio, 26, pruned_fci:pruned_pc
# Processing: audio, 28, pruned_fci:pruned_pc
# Processing: audio, 30, pruned_fci:pruned_pc
# Processing: audio, 34, pruned_fci:pruned_pc
# Processing: audio, 37, pruned_fci:pruned_pc
# Processing: audio, 39, pruned_fci:pruned_pc
# Processing: audio, 41, pruned_fci:pruned_pc
# Processing: audio, 42, pruned_fci:pruned_pc
# Processing: audio, 45, pruned_fci:pruned_pc
# Processing: audio, 46, pruned_fci:pruned_pc
# Processing: audio, 56, pruned_fci:pruned_pc
# Processing: audio, 64, pruned_fci:pruned_pc
# Processing: audio, 65, pruned_fci:pruned_pc
# Processing: physio, 16, ges:pruned_fci
# Processing: physio, 19, ges:pruned_fci
# Processing: physio, 23, ges:pruned_fci
# Processing: physio, 25, ges:pruned_fci
# Processing: physio, 26, ges:pruned_fci
# Processing: physio, 28, ges:pruned_fci
# Processing: physio, 30, ges:pruned_fci
# Processing: physio, 34, ges:pruned_fci
# Processing: physio, 37, ges:pruned_fci
# Processing: physio, 39, ges:pruned_fci
# Processing: physio, 41, ges:pruned_fci
# Processing: physio, 42, ges:pruned_fci
# Processing: physio, 45, ges:pruned_fci
# Processing: physio, 46, ges:pruned_fci
# Processing: physio, 56, ges:pruned_fci
# Processing: physio, 64, ges:pruned_fci
# Processing: physio, 65, ges:pruned_fci
# Processing: physio, 16, ges:pruned_pc
# Processing: physio, 19, ges:pruned_pc
# Processing: physio, 23, ges:pruned_pc
# Processing: physio, 25, ges:pruned_pc
# Processing: physio, 26, ges:pruned_pc
# Processing: physio, 28, ges:pruned_pc
# Processing: physio, 30, ges:pruned_pc
# Processing: physio, 34, ges:pruned_pc
# Processing: physio, 37, ges:pruned_pc
# Processing: physio, 39, ges:pruned_pc
# Processing: physio, 41, ges:pruned_pc
# Processing: physio, 42, ges:pruned_pc
# Processing: physio, 45, ges:pruned_pc
# Processing: physio, 46, ges:pruned_pc
# Processing: physio, 56, ges:pruned_pc
# Processing: physio, 64, ges:pruned_pc
# Processing: physio, 65, ges:pruned_pc
# Processing: physio, 16, pruned_fci:pruned_pc
# Processing: physio, 19, pruned_fci:pruned_pc
# Processing: physio, 21, pruned_fci:pruned_pc
# Processing: physio, 23, pruned_fci:pruned_pc
# Processing: physio, 25, pruned_fci:pruned_pc
# Processing: physio, 26, pruned_fci:pruned_pc
# Processing: physio, 28, pruned_fci:pruned_pc
# Processing: physio, 30, pruned_fci:pruned_pc
# Processing: physio, 34, pruned_fci:pruned_pc
# Processing: physio, 37, pruned_fci:pruned_pc
# Processing: physio, 39, pruned_fci:pruned_pc
# Processing: physio, 41, pruned_fci:pruned_pc
# Processing: physio, 42, pruned_fci:pruned_pc
# Processing: physio, 45, pruned_fci:pruned_pc
# Processing: physio, 46, pruned_fci:pruned_pc
# Processing: physio, 56, pruned_fci:pruned_pc
# Processing: physio, 64, pruned_fci:pruned_pc
# Processing: physio, 65, pruned_fci:pruned_pc

# %%
for modality, methods in data.items():
    method_pairs = list(combinations(methods, 2))
    for pair in method_pairs:
        participants = set(methods[pair[0]]) & set(methods[pair[1]])
        for participant_id in sorted(participants):
            print(f"Processing: {modality}, {participant_id}, {pair[0]}:{pair[1]}")
            dag_path_0 = f"../results_dag/{modality}/{pair[0]}_dag_participant_{participant_id}.pkl"
            dag_path_1 = f"../results_dag/{modality}/{pair[1]}_dag_participant_{participant_id}.pkl"

            edges_0 = get_edges(dag_path_0, pair[0])
            edges_1 = get_edges(dag_path_1, pair[1])

            jaccard = jaccard_similarity(edges_0, edges_1)

            results_df.loc[participant_id, (modality, f"{pair[0]}:{pair[1]}")] = jaccard
# Out:
# Processing: visual, 16, ges:pruned_fci
# Processing: visual, 19, ges:pruned_fci
# Processing: visual, 23, ges:pruned_fci
# Processing: visual, 25, ges:pruned_fci
# Processing: visual, 26, ges:pruned_fci
# Processing: visual, 28, ges:pruned_fci
# Processing: visual, 30, ges:pruned_fci
# Processing: visual, 34, ges:pruned_fci
# Processing: visual, 37, ges:pruned_fci
# Processing: visual, 39, ges:pruned_fci
# Processing: visual, 42, ges:pruned_fci
# Processing: visual, 45, ges:pruned_fci
# Processing: visual, 46, ges:pruned_fci
# Processing: visual, 56, ges:pruned_fci
# Processing: visual, 64, ges:pruned_fci
# Processing: visual, 65, ges:pruned_fci
# Processing: visual, 16, ges:pruned_pc
# Processing: visual, 19, ges:pruned_pc
# Processing: visual, 23, ges:pruned_pc
# Processing: visual, 25, ges:pruned_pc
# Processing: visual, 26, ges:pruned_pc
# Processing: visual, 28, ges:pruned_pc
# Processing: visual, 30, ges:pruned_pc
# Processing: visual, 34, ges:pruned_pc
# Processing: visual, 37, ges:pruned_pc
# Processing: visual, 39, ges:pruned_pc
# Processing: visual, 42, ges:pruned_pc
# Processing: visual, 45, ges:pruned_pc
# Processing: visual, 46, ges:pruned_pc
# Processing: visual, 56, ges:pruned_pc
# Processing: visual, 64, ges:pruned_pc
# Processing: visual, 65, ges:pruned_pc
# Processing: visual, 16, pruned_fci:pruned_pc
# Processing: visual, 19, pruned_fci:pruned_pc
# Processing: visual, 21, pruned_fci:pruned_pc
# Processing: visual, 23, pruned_fci:pruned_pc
# Processing: visual, 25, pruned_fci:pruned_pc
# Processing: visual, 26, pruned_fci:pruned_pc
# Processing: visual, 28, pruned_fci:pruned_pc
# Processing: visual, 30, pruned_fci:pruned_pc
# Processing: visual, 34, pruned_fci:pruned_pc
# Processing: visual, 37, pruned_fci:pruned_pc
# Processing: visual, 39, pruned_fci:pruned_pc
# Processing: visual, 41, pruned_fci:pruned_pc
# Processing: visual, 42, pruned_fci:pruned_pc
# Processing: visual, 45, pruned_fci:pruned_pc
# Processing: visual, 46, pruned_fci:pruned_pc
# Processing: visual, 56, pruned_fci:pruned_pc
# Processing: visual, 64, pruned_fci:pruned_pc
# Processing: visual, 65, pruned_fci:pruned_pc
# Processing: audio, 16, ges:pruned_fci
# Processing: audio, 19, ges:pruned_fci
# Processing: audio, 21, ges:pruned_fci
# Processing: audio, 23, ges:pruned_fci
# Processing: audio, 25, ges:pruned_fci
# Processing: audio, 26, ges:pruned_fci
# Processing: audio, 28, ges:pruned_fci
# Processing: audio, 30, ges:pruned_fci
# Processing: audio, 34, ges:pruned_fci
# Processing: audio, 37, ges:pruned_fci
# Processing: audio, 39, ges:pruned_fci
# Processing: audio, 41, ges:pruned_fci
# Processing: audio, 42, ges:pruned_fci
# Processing: audio, 45, ges:pruned_fci
# Processing: audio, 46, ges:pruned_fci
# Processing: audio, 56, ges:pruned_fci
# Processing: audio, 64, ges:pruned_fci
# Processing: audio, 65, ges:pruned_fci
# Processing: audio, 16, ges:pruned_pc
# Processing: audio, 19, ges:pruned_pc
# Processing: audio, 21, ges:pruned_pc
# Processing: audio, 23, ges:pruned_pc
# Processing: audio, 25, ges:pruned_pc
# Processing: audio, 26, ges:pruned_pc
# Processing: audio, 28, ges:pruned_pc
# Processing: audio, 30, ges:pruned_pc
# Processing: audio, 34, ges:pruned_pc
# Processing: audio, 37, ges:pruned_pc
# Processing: audio, 39, ges:pruned_pc
# Processing: audio, 41, ges:pruned_pc
# Processing: audio, 42, ges:pruned_pc
# Processing: audio, 45, ges:pruned_pc
# Processing: audio, 46, ges:pruned_pc
# Processing: audio, 56, ges:pruned_pc
# Processing: audio, 64, ges:pruned_pc
# Processing: audio, 65, ges:pruned_pc
# Processing: audio, 16, pruned_fci:pruned_pc
# Processing: audio, 19, pruned_fci:pruned_pc
# Processing: audio, 21, pruned_fci:pruned_pc
# Processing: audio, 23, pruned_fci:pruned_pc
# Processing: audio, 25, pruned_fci:pruned_pc
# Processing: audio, 26, pruned_fci:pruned_pc
# Processing: audio, 28, pruned_fci:pruned_pc
# Processing: audio, 30, pruned_fci:pruned_pc
# Processing: audio, 34, pruned_fci:pruned_pc
# Processing: audio, 37, pruned_fci:pruned_pc
# Processing: audio, 39, pruned_fci:pruned_pc
# Processing: audio, 41, pruned_fci:pruned_pc
# Processing: audio, 42, pruned_fci:pruned_pc
# Processing: audio, 45, pruned_fci:pruned_pc
# Processing: audio, 46, pruned_fci:pruned_pc
# Processing: audio, 56, pruned_fci:pruned_pc
# Processing: audio, 64, pruned_fci:pruned_pc
# Processing: audio, 65, pruned_fci:pruned_pc
# Processing: physio, 16, ges:pruned_fci
# Processing: physio, 19, ges:pruned_fci
# Processing: physio, 23, ges:pruned_fci
# Processing: physio, 25, ges:pruned_fci
# Processing: physio, 26, ges:pruned_fci
# Processing: physio, 28, ges:pruned_fci
# Processing: physio, 30, ges:pruned_fci
# Processing: physio, 34, ges:pruned_fci
# Processing: physio, 37, ges:pruned_fci
# Processing: physio, 39, ges:pruned_fci
# Processing: physio, 41, ges:pruned_fci
# Processing: physio, 42, ges:pruned_fci
# Processing: physio, 45, ges:pruned_fci
# Processing: physio, 46, ges:pruned_fci
# Processing: physio, 56, ges:pruned_fci
# Processing: physio, 64, ges:pruned_fci
# Processing: physio, 65, ges:pruned_fci
# Processing: physio, 16, ges:pruned_pc
# Processing: physio, 19, ges:pruned_pc
# Processing: physio, 23, ges:pruned_pc
# Processing: physio, 25, ges:pruned_pc
# Processing: physio, 26, ges:pruned_pc
# Processing: physio, 28, ges:pruned_pc
# Processing: physio, 30, ges:pruned_pc
# Processing: physio, 34, ges:pruned_pc
# Processing: physio, 37, ges:pruned_pc
# Processing: physio, 39, ges:pruned_pc
# Processing: physio, 41, ges:pruned_pc
# Processing: physio, 42, ges:pruned_pc
# Processing: physio, 45, ges:pruned_pc
# Processing: physio, 46, ges:pruned_pc
# Processing: physio, 56, ges:pruned_pc
# Processing: physio, 64, ges:pruned_pc
# Processing: physio, 65, ges:pruned_pc
# Processing: physio, 16, pruned_fci:pruned_pc
# Processing: physio, 19, pruned_fci:pruned_pc
# Processing: physio, 21, pruned_fci:pruned_pc
# Processing: physio, 23, pruned_fci:pruned_pc
# Processing: physio, 25, pruned_fci:pruned_pc
# Processing: physio, 26, pruned_fci:pruned_pc
# Processing: physio, 28, pruned_fci:pruned_pc
# Processing: physio, 30, pruned_fci:pruned_pc
# Processing: physio, 34, pruned_fci:pruned_pc
# Processing: physio, 37, pruned_fci:pruned_pc
# Processing: physio, 39, pruned_fci:pruned_pc
# Processing: physio, 41, pruned_fci:pruned_pc
# Processing: physio, 42, pruned_fci:pruned_pc
# Processing: physio, 45, pruned_fci:pruned_pc
# Processing: physio, 46, pruned_fci:pruned_pc
# Processing: physio, 56, pruned_fci:pruned_pc
# Processing: physio, 64, pruned_fci:pruned_pc
# Processing: physio, 65, pruned_fci:pruned_pc

# %%
results_df.to_csv("inter_graph_jaccard.csv")
